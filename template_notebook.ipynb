# %% [markdown]
# # [Lab Title Here]
# <sub>![Day N](https://img.shields.io/badge/Day%20N-Topic%20Name-4285F4)</sub>
#
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/YOUR-ORG/gcp-training-labs/blob/main/dayN-topic/NN_lab_name.ipynb)
#
# **What you'll do:** one or two sentences describing the hands-on outcome of this lab.
#
# **Estimated cost:** free tier / ~$X if run to completion — see cost warnings inline below.
#
# **Prerequisites:** run `_shared/setup_check.ipynb` first if you haven't already.

# %% [markdown]
# ## Configuration
#
# Edit the four values below to match your own GCP project, then **Runtime → Run all**.
# This is the *only* cell you need to change — every other cell in this notebook uses these variables.

# %%
# @title Configuration — EDIT THESE 4 VALUES, then Runtime > Run all
PROJECT_ID   = "your-project-id-here"     # gcloud config get-value project
REGION       = "us-central1"
BUCKET_NAME  = f"{PROJECT_ID}-training-bucket"
DATASET_NAME = "training_dataset"

# Do not edit below this line
# !gcloud config set project {PROJECT_ID}

# %% [markdown]
# ## Setup
#
# Authenticate this Colab session against your GCP project and install/import any required libraries.

# %%
from google.colab import auth
auth.authenticate_user()

# Uncomment if this lab needs extra packages beyond what Colab ships with:
# !pip install --quiet <package-name>

# %% [markdown]
# ## [Concept 1 Name]
#
# Explain the concept in plain language before the code: what it is, why it matters, and what
# the participant should notice in the output. Include a `gcloud`/`gsutil`/`bq` CLI equivalent
# where relevant, and flag any evolving/preview API surface with a caveat.

# %%
# NOTE: replace placeholder values below with real names/paths as needed for this lab.
# COST WARNING: flag here if this cell creates a billed resource (e.g. BigQuery slot
# reservation, Vertex training job, always-on Dataflow job).

# Python SDK example:
# from google.cloud import storage
# client = storage.Client(project=PROJECT_ID)
# ...

# CLI equivalent:
# !gsutil ls gs://{BUCKET_NAME}

# %% [markdown]
# ## Cleanup
#
# If this lab created billed resources (buckets, reservations, endpoints, etc.), tear them down
# now or run `_shared/cleanup.ipynb` at the end of the day to avoid ongoing charges.
